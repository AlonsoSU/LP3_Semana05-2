# %%
#VIDEO PARA 2 VARIABLES QUE COMPARTEN EL MISMO OBJETO

caja1=["pelota","llave","casco"]
caja2=["cuaderno","linter","borrador"]

caja3=caja1

# %%
caja3
# Out:
# ['pelota', 'llave', 'casco']

# %%
from IPython.display import Image
Image('Compartir_objetos.jpg', width=600,height=300)

# %%
caja1 is caja2
# Out:
# False
